# %%
# %matplotlib inline

import os
import re
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
FACE_MESH = pd.read_csv('faceMesh/face_mesh.csv')

# %%
def landmarks_mapper(video: str, cleansed_data: bool):
    
    OPENFACE_LANDMARKS = [i for i in range(17, 68)]
    
    if cleansed_data:
        OPENFACE_DIR = 'openFace/processed_cleansed/'
        MEDIAPIPE_DIR = 'mediaPipe/processed_cleansed/'
        of_df = pd.read_csv(OPENFACE_DIR + video + '_openface_cleansed.csv')
        mp_df = pd.read_csv(MEDIAPIPE_DIR + video + '_mediapipe_cleansed.csv')
    else:
        OPENFACE_DIR = 'openFace/processed/'
        MEDIAPIPE_DIR = 'mediaPipe/processed/'
        of_df = pd.read_csv(OPENFACE_DIR + video + '_openface.csv')
        mp_df = pd.read_csv(MEDIAPIPE_DIR + video + '_mediapipe.csv')
    
    final_df = of_df['frame'] # initialize the final dataframe
    for i, landmark in enumerate(OPENFACE_LANDMARKS):

        mask = (FACE_MESH['openFace_landmark'] == landmark) # group the mediapipe landmarks by the openface landmark

        tmp1_df = of_df[[f'x_{landmark}', f'y_{landmark}']] # select the columns from the openface dataframe
        tmp1_df.columns = [f'openface_x_{landmark}', f'openface_y_{landmark}'] # rename the columns
        
        mediaPipe_landmarks_X = ['x_'+str(ID) for ID in FACE_MESH[mask].id] # collect the X coordinate
        mediaPipe_landmarks_Y = ['y_'+str(ID) for ID in FACE_MESH[mask].id] # collect the Y coordinate
        
        tmp2_df = pd.DataFrame({f'mediapipe_x_{landmark}':mp_df[mediaPipe_landmarks_X].mean(axis=1),
                                f'mediapipe_y_{landmark}':mp_df[mediaPipe_landmarks_Y].mean(axis=1)})
        
        final_df = pd.concat([final_df, tmp1_df, tmp2_df], axis=1)
        
    return final_df

# %% [markdown]
# # Pearson, R2 e CCC

# %%
def pearson(df: pd.DataFrame):
    
    lndmk_pearson = []
    for i in range(17, 68):
        
        x_pearson = pearsonr(df[f'openface_x_{i}'].to_numpy(), df[f'mediapipe_x_{i}'].to_numpy())[0]
        y_pearson = pearsonr(df[f'openface_y_{i}'].to_numpy(), df[f'mediapipe_y_{i}'].to_numpy())[0]
        lndmk_pearson.append((x_pearson+y_pearson)/2)
    
    video_pearson = np.mean(lndmk_pearson)
    
    return video_pearson

# %%
def r2(df: pd.DataFrame):
    
    lndmk_r2 = []
    for i in range(17, 68):
        
        x_r2 = r2_score(df[f'mediapipe_x_{i}'].to_numpy(), df[f'openface_x_{i}'].to_numpy())
        y_r2 = r2_score(df[f'mediapipe_y_{i}'].to_numpy(), df[f'openface_y_{i}'].to_numpy())
        lndmk_r2.append((x_r2+y_r2)/2)
    
    video_r2 = np.mean(lndmk_r2)
    
    return video_r2

# %%
def rhoc(x,y):

    sxy = np.sum((x - x.mean())*(y - y.mean()))/x.shape[0]
    rhoc = 2*sxy / (np.var(x) + np.var(y) + (x.mean() - y.mean())**2)
    
    return rhoc

# %%
def ccc(df: pd.DataFrame):
    
    lndmk_ccc = []
    for i in range(17,68):
        
        x_ccc = rhoc(df[f'openface_x_{i}'].to_numpy(), df[f'mediapipe_x_{i}'].to_numpy())
        y_ccc = rhoc(df[f'openface_y_{i}'].to_numpy(), df[f'mediapipe_y_{i}'].to_numpy())
        lndmk_ccc.append((x_ccc+y_ccc)/2)
        
    video_ccc = np.mean(lndmk_ccc)
    
    return video_ccc

# %% [markdown]
# ### Raw data

# %%
videos = []
videos_pearson = []
videos_r2 = []
videos_ccc = []
for video in os.listdir('dataset/ElderReact_Data/ElderReact_train/'):
    video = video[:-4]
    videos.append(video)
    
    landmarks = landmarks_mapper(video, cleansed_data=False)
    videos_pearson.append(pearson(landmarks))
    videos_r2.append(r2(landmarks))
    videos_ccc.append(ccc(landmarks))

extracted_features_df = pd.DataFrame({'video': videos, 'pearson': videos_pearson, 'r2': videos_r2, 'ccc': videos_ccc})
# %store extracted_features_df
extracted_features_df.to_csv('pearson_r2_ccc.csv', index=False)
extracted_features_df
# Out:
# Stored 'extracted_features_df' (DataFrame)
#                    video   pearson        r2       ccc
# 0     whack_your_boss_12  0.994929  0.944251  0.973614
# 1        happy_wheels_54  0.982861  0.947330  0.974229
# 2    would_you_rather_29  0.996142  0.950409  0.976429
# 3      play_red_dead_138  0.843837  0.535926  0.796190
# 4     Branda_schmitz_116  0.995133  0.947977  0.975390
# ..                   ...       ...       ...       ...
# 610      bully_burger_54  0.993922  0.940392  0.971835
# 611   game_of_thrones_16  0.997744  0.964629  0.982836
# 612              qwop_38  0.984433  0.834965  0.932025
# 613           cuphead_58  0.992749  0.948167  0.974880
# 614         rammstein_49  0.995333  0.948336  0.975094
#
# [615 rows x 4 columns]

# %% [markdown]
# ### Cleansed data

# %%
videos = []
videos_pearson = []
videos_r2 = []
videos_ccc = []
for video in os.listdir('dataset/ElderReact_Data/ElderReact_train/'):
    video = video[:-4]
    videos.append(video)
    
    landmarks = landmarks_mapper(video, cleansed_data=True)
    videos_pearson.append(pearson(landmarks))
    videos_r2.append(r2(landmarks))
    videos_ccc.append(ccc(landmarks))

extracted_features_df_cleansed = pd.DataFrame({'video': videos, 'pearson': videos_pearson, 'r2': videos_r2, 'ccc': videos_ccc})
# %store extracted_features_df_cleansed
extracted_features_df_cleansed.to_csv('pearson_r2_ccc_cleansed.csv', index=False)
extracted_features_df_cleansed
# Out:
# Stored 'extracted_features_df_cleansed' (DataFrame)
#                    video   pearson        r2       ccc
# 0     whack_your_boss_12  0.994929  0.944251  0.973614
# 1        happy_wheels_54  0.982861  0.947330  0.974229
# 2    would_you_rather_29  0.996142  0.950409  0.976429
# 3      play_red_dead_138  0.843837  0.535926  0.796190
# 4     Branda_schmitz_116  0.995133  0.947977  0.975390
# ..                   ...       ...       ...       ...
# 610      bully_burger_54  0.993922  0.940392  0.971835
# 611   game_of_thrones_16  0.997744  0.964629  0.982836
# 612              qwop_38  0.984433  0.834965  0.932025
# 613           cuphead_58  0.992749  0.948167  0.974880
# 614         rammstein_49  0.995333  0.948336  0.975094
#
# [615 rows x 4 columns]

# %%
sns.set(rc={"figure.dpi":120})
sns.set_context('notebook')
sns.set_style("ticks")

fig, axes = plt.subplots(2,2, figsize=(10,5))
fig.suptitle('Plots of Pearson, R2 and CCC of the video dataset')
axes = axes.flatten()

# Pearson
axes[0].set_title('Pearson Coefficient')
sns.histplot(data=extracted_features_df, x='pearson', bins=615, ax=axes[0])

# R2
axes[1].set_title('Coefficient of Determination')
sns.histplot(data=extracted_features_df, x='r2', bins=615, ax=axes[1])

# CCC
axes[2].set_title('Concordance Correlation Coefficient')
sns.histplot(data=extracted_features_df, x='ccc', bins=615, ax=axes[2])

fig.delaxes(axes[3])
fig.tight_layout()
plt.show()

# %%
df = extracted_features_df[extracted_features_df.pearson < 0.8][['video', 'pearson']].sort_values(by='pearson')
videos_low_pearson = set(df['video'])
print('Numero di video con coefficiente di Pearson minore di 0.8:', len(df))
df
# Out:
# Numero di video con coefficiente di Pearson minore di 0.8: 19
#                     video   pearson
# 105                gta2_2 -0.433737
# 605                gta1_1  0.062133
# 145               qwop_40  0.255495
# 87         david_bowie_36  0.297967
# 490               qwop_93  0.300300
# 243       david_bowie_109  0.307798
# 373               gta2_26  0.396666
# 186        david_bowie_13  0.508014
# 408           fatality_17  0.523069
# 367     play_lastofus_202  0.572700
# 440              50_50_70  0.622480
# 96        happy_wheels_97  0.652695
# 279           fatality_15  0.676326
# 136  TRY_NOT_LOOK_AWAY_21  0.692060
# 203            eminem_142  0.701040
# 242       battlefield1_50  0.718162
# 63             fatality_9  0.724103
# 318         dolan_dark_75  0.774220
# 454               gta1_34  0.782463

# %%
df = extracted_features_df[extracted_features_df.r2 < 0.8].sort_values(by='r2')
videos_low_r2 = set(df['video'])
print('Numero di video con R2 minore di 0.8:', len(df))
df
# Out:
# Numero di video con R2 minore di 0.8: 219
#                     video   pearson          r2       ccc
# 605                gta1_1  0.062133 -518.425632  0.009935
# 490               qwop_93  0.300300  -36.505561  0.256064
# 318         dolan_dark_75  0.774220  -26.681080  0.274845
# 136  TRY_NOT_LOOK_AWAY_21  0.692060  -17.041159  0.362347
# 493              50_50_77  0.830610  -15.769022  0.397240
# ..                    ...       ...         ...       ...
# 291               gta2_33  0.993355    0.795923  0.915034
# 568  TRY_NOT_LOOK_AWAY_20  0.980994    0.797080  0.914788
# 160           fatality_11  0.986165    0.797105  0.915392
# 513       happy_wheels_51  0.990005    0.798097  0.922798
# 364       happy_wheels_64  0.956734    0.799710  0.905275
#
# [219 rows x 4 columns]

# %%
df = extracted_features_df[extracted_features_df.ccc < 0.8].sort_values(by='ccc')
videos_low_ccc = set(df['video'])
print('Numero di video con ccc minore di 0.8:', len(df))
df
# Out:
# Numero di video con ccc minore di 0.8: 98
#                  video   pearson          r2       ccc
# 105             gta2_2 -0.433737   -7.769504 -0.279235
# 605             gta1_1  0.062133 -518.425632  0.009935
# 87      david_bowie_36  0.297967   -0.142668  0.166869
# 145            qwop_40  0.255495   -4.000243  0.195560
# 243    david_bowie_109  0.307798   -0.043078  0.254961
# ..                 ...       ...         ...       ...
# 3    play_red_dead_138  0.843837    0.535926  0.796190
# 218       heartbeat_23  0.967683    0.245664  0.797000
# 84   play_lastofus_146  0.956649    0.402055  0.798034
# 484    battlefield1_25  0.950067    0.078792  0.799125
# 529        burnshoes_7  0.962255    0.342114  0.799869
#
# [98 rows x 4 columns]

# %%
videos_low_pearson.intersection(videos_low_r2).intersection(videos_low_ccc)
# Out:
# {'50_50_70',
#  'TRY_NOT_LOOK_AWAY_21',
#  'battlefield1_50',
#  'david_bowie_109',
#  'david_bowie_13',
#  'david_bowie_36',
#  'dolan_dark_75',
#  'eminem_142',
#  'fatality_15',
#  'fatality_17',
#  'fatality_9',
#  'gta1_1',
#  'gta1_34',
#  'gta2_2',
#  'gta2_26',
#  'happy_wheels_97',
#  'play_lastofus_202',
#  'qwop_40',
#  'qwop_93'}
