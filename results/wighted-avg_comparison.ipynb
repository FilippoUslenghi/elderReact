# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Weighted avg

# %% [markdown]
# Per ogni emozione evidenzio quale feature ha avuto il punteggio massimo in un determinato modello di ML

# %%
print('Logistic regression')
logistic_df = pd.read_csv('logistic_regression/f1_score.csv', header=[0,1], index_col=[0,1])
logistic_df = logistic_df.drop(columns=['tilted','frontal'], level=1)
logistic_df = logistic_df.drop(index=['macro_avg', 'label_1'], level=0).reset_index(level=0, drop=True)
display(logistic_df.style.highlight_max(color='lightgreen', axis=1).format('{:.2f}'))
# Out:
# Logistic regression
# <style  type="text/css" >
# #T_83bb7_row0_col2,#T_83bb7_row1_col1,#T_83bb7_row2_col0,#T_83bb7_row3_col2,#T_83bb7_row4_col2,#T_83bb7_row5_col3,#T_83bb7_row6_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_83bb7_" ><thead>    <tr>        <th class="index_name level0" >features</th>        <th class="col_heading level0 col0" >delaunay</th>        <th class="col_heading level0 col1" >au_intensities</th>        <th class="col_heading level0 col2" >au_activations</th>        <th class="col_heading level0 col3" >au_intensities_activations</th>    </tr>    <tr>        <th class="index_name level1" >pose</th>        <th class="col_heading level1 col0" >none</th>        <th class="col_heading level1 col1" >none</th>        <th class="col_heading level1 col2" >none</th>        <th class="col_heading level1 col3" >none</th>    </tr>    <tr>        <th class="index_name level0" >emotion</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83bb7_level0_row0" class="row_heading level0 row0" >anger</th>
#                         <td id="T_83bb7_row0_col0" class="data row0 col0" >0.57</td>
#                         <td id="T_83bb7_row0_col1" class="data row0 col1" >0.57</td>
#                         <td id="T_83bb7_row0_col2" class="data row0 col2" >0.63</td>
#                         <td id="T_83bb7_row0_col3" class="data row0 col3" >0.60</td>
#             </tr>
#             <tr>
#                         <th id="T_83bb7_level0_row1" class="row_heading level0 row1" >disgust</th>
#                         <td id="T_83bb7_row1_col0" class="data row1 col0" >0.53</td>
#                         <td id="T_83bb7_row1_col1" class="data row1 col1" >0.63</td>
#                         <td id="T_83bb7_row1_col2" class="data row1 col2" >0.62</td>
#                         <td id="T_83bb7_row1_col3" class="data row1 col3" >0.61</td>
#             </tr>
#             <tr>
#                         <th id="T_83bb7_level0_row2" class="row_heading level0 row2" >fear</th>
#                         <td id="T_83bb7_row2_col0" class="data row2 col0" >0.74</td>
#                         <td id="T_83bb7_row2_col1" class="data row2 col1" >0.63</td>
#                         <td id="T_83bb7_row2_col2" class="data row2 col2" >0.62</td>
#                         <td id="T_83bb7_row2_col3" class="data row2 col3" >0.67</td>
#             </tr>
#             <tr>
#                         <th id="T_83bb7_level0_row3" class="row_heading level0 row3" >happiness</th>
#                         <td id="T_83bb7_row3_col0" class="data row3 col0" >0.59</td>
#                         <td id="T_83bb7_row3_col1" class="data row3 col1" >0.65</td>
#                         <td id="T_83bb7_row3_col2" class="data row3 col2" >0.68</td>
#                         <td id="T_83bb7_row3_col3" class="data row3 col3" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_83bb7_level0_row4" class="row_heading level0 row4" >sadness</th>
#                         <td id="T_83bb7_row4_col0" class="data row4 col0" >0.55</td>
#                         <td id="T_83bb7_row4_col1" class="data row4 col1" >0.56</td>
#                         <td id="T_83bb7_row4_col2" class="data row4 col2" >0.62</td>
#                         <td id="T_83bb7_row4_col3" class="data row4 col3" >0.57</td>
#             </tr>
#             <tr>
#                         <th id="T_83bb7_level0_row5" class="row_heading level0 row5" >surprise</th>
#                         <td id="T_83bb7_row5_col0" class="data row5 col0" >0.57</td>
#                         <td id="T_83bb7_row5_col1" class="data row5 col1" >0.60</td>
#                         <td id="T_83bb7_row5_col2" class="data row5 col2" >0.58</td>
#                         <td id="T_83bb7_row5_col3" class="data row5 col3" >0.62</td>
#             </tr>
#             <tr>
#                         <th id="T_83bb7_level0_row6" class="row_heading level0 row6" >valence</th>
#                         <td id="T_83bb7_row6_col0" class="data row6 col0" >0.52</td>
#                         <td id="T_83bb7_row6_col1" class="data row6 col1" >0.64</td>
#                         <td id="T_83bb7_row6_col2" class="data row6 col2" >0.61</td>
#                         <td id="T_83bb7_row6_col3" class="data row6 col3" >0.63</td>
#             </tr>
#     </tbody></table>

# %%
print('Linear SVM')
linear_df = pd.read_csv('linear_SVM/f1_score.csv', header=[0,1], index_col=[0,1])
linear_df = linear_df.drop(columns=['tilted','frontal'], level=1)
linear_df = linear_df.drop(index=['macro_avg', 'label_1'], level=0).reset_index(level=0, drop=True)
linear_df.style.highlight_max(color='lightgreen', axis=1).format('{:.2f}')
# Out:
# Linear SVM
# <style  type="text/css" >
# #T_ce092_row0_col3,#T_ce092_row1_col1,#T_ce092_row2_col0,#T_ce092_row3_col1,#T_ce092_row3_col2,#T_ce092_row4_col3,#T_ce092_row5_col3,#T_ce092_row6_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_ce092_" ><thead>    <tr>        <th class="index_name level0" >features</th>        <th class="col_heading level0 col0" >delaunay</th>        <th class="col_heading level0 col1" >au_intensities</th>        <th class="col_heading level0 col2" >au_activations</th>        <th class="col_heading level0 col3" >au_intensities_activations</th>    </tr>    <tr>        <th class="index_name level1" >pose</th>        <th class="col_heading level1 col0" >none</th>        <th class="col_heading level1 col1" >none</th>        <th class="col_heading level1 col2" >none</th>        <th class="col_heading level1 col3" >none</th>    </tr>    <tr>        <th class="index_name level0" >emotion</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce092_level0_row0" class="row_heading level0 row0" >anger</th>
#                         <td id="T_ce092_row0_col0" class="data row0 col0" >0.58</td>
#                         <td id="T_ce092_row0_col1" class="data row0 col1" >0.63</td>
#                         <td id="T_ce092_row0_col2" class="data row0 col2" >0.63</td>
#                         <td id="T_ce092_row0_col3" class="data row0 col3" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_ce092_level0_row1" class="row_heading level0 row1" >disgust</th>
#                         <td id="T_ce092_row1_col0" class="data row1 col0" >0.55</td>
#                         <td id="T_ce092_row1_col1" class="data row1 col1" >0.69</td>
#                         <td id="T_ce092_row1_col2" class="data row1 col2" >0.57</td>
#                         <td id="T_ce092_row1_col3" class="data row1 col3" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_ce092_level0_row2" class="row_heading level0 row2" >fear</th>
#                         <td id="T_ce092_row2_col0" class="data row2 col0" >0.71</td>
#                         <td id="T_ce092_row2_col1" class="data row2 col1" >0.66</td>
#                         <td id="T_ce092_row2_col2" class="data row2 col2" >0.63</td>
#                         <td id="T_ce092_row2_col3" class="data row2 col3" >0.62</td>
#             </tr>
#             <tr>
#                         <th id="T_ce092_level0_row3" class="row_heading level0 row3" >happiness</th>
#                         <td id="T_ce092_row3_col0" class="data row3 col0" >0.61</td>
#                         <td id="T_ce092_row3_col1" class="data row3 col1" >0.66</td>
#                         <td id="T_ce092_row3_col2" class="data row3 col2" >0.66</td>
#                         <td id="T_ce092_row3_col3" class="data row3 col3" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_ce092_level0_row4" class="row_heading level0 row4" >sadness</th>
#                         <td id="T_ce092_row4_col0" class="data row4 col0" >0.59</td>
#                         <td id="T_ce092_row4_col1" class="data row4 col1" >0.62</td>
#                         <td id="T_ce092_row4_col2" class="data row4 col2" >0.61</td>
#                         <td id="T_ce092_row4_col3" class="data row4 col3" >0.64</td>
#             </tr>
#             <tr>
#                         <th id="T_ce092_level0_row5" class="row_heading level0 row5" >surprise</th>
#                         <td id="T_ce092_row5_col0" class="data row5 col0" >0.57</td>
#                         <td id="T_ce092_row5_col1" class="data row5 col1" >0.58</td>
#                         <td id="T_ce092_row5_col2" class="data row5 col2" >0.56</td>
#                         <td id="T_ce092_row5_col3" class="data row5 col3" >0.61</td>
#             </tr>
#             <tr>
#                         <th id="T_ce092_level0_row6" class="row_heading level0 row6" >valence</th>
#                         <td id="T_ce092_row6_col0" class="data row6 col0" >0.54</td>
#                         <td id="T_ce092_row6_col1" class="data row6 col1" >0.62</td>
#                         <td id="T_ce092_row6_col2" class="data row6 col2" >0.61</td>
#                         <td id="T_ce092_row6_col3" class="data row6 col3" >0.60</td>
#             </tr>
#     </tbody></table>

# %%
print('Kernel SVM')
kernel_df = pd.read_csv('kernel_SVM/f1_score.csv', header=[0,1], index_col=[0,1])
kernel_df = kernel_df.drop(columns=['tilted','frontal'], level=1)
kernel_df = kernel_df.drop(index=['macro_avg', 'label_1'], level=0).reset_index(level=0, drop=True)
kernel_df.style.highlight_max(color='lightgreen', axis=1).format('{:.2f}')
# Out:
# Kernel SVM
# <style  type="text/css" >
# #T_daa8b_row0_col1,#T_daa8b_row1_col0,#T_daa8b_row2_col2,#T_daa8b_row3_col2,#T_daa8b_row4_col1,#T_daa8b_row5_col3,#T_daa8b_row6_col2{
#             background-color:  lightgreen;
#         }</style><table id="T_daa8b_" ><thead>    <tr>        <th class="index_name level0" >features</th>        <th class="col_heading level0 col0" >delaunay</th>        <th class="col_heading level0 col1" >au_intensities</th>        <th class="col_heading level0 col2" >au_activations</th>        <th class="col_heading level0 col3" >au_intensities_activations</th>    </tr>    <tr>        <th class="index_name level1" >pose</th>        <th class="col_heading level1 col0" >none</th>        <th class="col_heading level1 col1" >none</th>        <th class="col_heading level1 col2" >none</th>        <th class="col_heading level1 col3" >none</th>    </tr>    <tr>        <th class="index_name level0" >emotion</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_daa8b_level0_row0" class="row_heading level0 row0" >anger</th>
#                         <td id="T_daa8b_row0_col0" class="data row0 col0" >0.55</td>
#                         <td id="T_daa8b_row0_col1" class="data row0 col1" >0.61</td>
#                         <td id="T_daa8b_row0_col2" class="data row0 col2" >0.59</td>
#                         <td id="T_daa8b_row0_col3" class="data row0 col3" >0.52</td>
#             </tr>
#             <tr>
#                         <th id="T_daa8b_level0_row1" class="row_heading level0 row1" >disgust</th>
#                         <td id="T_daa8b_row1_col0" class="data row1 col0" >0.67</td>
#                         <td id="T_daa8b_row1_col1" class="data row1 col1" >0.63</td>
#                         <td id="T_daa8b_row1_col2" class="data row1 col2" >0.58</td>
#                         <td id="T_daa8b_row1_col3" class="data row1 col3" >0.55</td>
#             </tr>
#             <tr>
#                         <th id="T_daa8b_level0_row2" class="row_heading level0 row2" >fear</th>
#                         <td id="T_daa8b_row2_col0" class="data row2 col0" >0.59</td>
#                         <td id="T_daa8b_row2_col1" class="data row2 col1" >0.64</td>
#                         <td id="T_daa8b_row2_col2" class="data row2 col2" >0.66</td>
#                         <td id="T_daa8b_row2_col3" class="data row2 col3" >0.57</td>
#             </tr>
#             <tr>
#                         <th id="T_daa8b_level0_row3" class="row_heading level0 row3" >happiness</th>
#                         <td id="T_daa8b_row3_col0" class="data row3 col0" >0.52</td>
#                         <td id="T_daa8b_row3_col1" class="data row3 col1" >0.55</td>
#                         <td id="T_daa8b_row3_col2" class="data row3 col2" >0.66</td>
#                         <td id="T_daa8b_row3_col3" class="data row3 col3" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_daa8b_level0_row4" class="row_heading level0 row4" >sadness</th>
#                         <td id="T_daa8b_row4_col0" class="data row4 col0" >0.55</td>
#                         <td id="T_daa8b_row4_col1" class="data row4 col1" >0.58</td>
#                         <td id="T_daa8b_row4_col2" class="data row4 col2" >0.56</td>
#                         <td id="T_daa8b_row4_col3" class="data row4 col3" >0.51</td>
#             </tr>
#             <tr>
#                         <th id="T_daa8b_level0_row5" class="row_heading level0 row5" >surprise</th>
#                         <td id="T_daa8b_row5_col0" class="data row5 col0" >0.50</td>
#                         <td id="T_daa8b_row5_col1" class="data row5 col1" >0.55</td>
#                         <td id="T_daa8b_row5_col2" class="data row5 col2" >0.55</td>
#                         <td id="T_daa8b_row5_col3" class="data row5 col3" >0.56</td>
#             </tr>
#             <tr>
#                         <th id="T_daa8b_level0_row6" class="row_heading level0 row6" >valence</th>
#                         <td id="T_daa8b_row6_col0" class="data row6 col0" >0.48</td>
#                         <td id="T_daa8b_row6_col1" class="data row6 col1" >0.52</td>
#                         <td id="T_daa8b_row6_col2" class="data row6 col2" >0.63</td>
#                         <td id="T_daa8b_row6_col3" class="data row6 col3" >0.51</td>
#             </tr>
#     </tbody></table>

# %%
print('LSTM')
lstm_df = pd.read_csv('LSTM/f1_score.csv', header=0, index_col=[0,1], names=['au_intensities', 'au_activations', 'au_intensities_activations'], skiprows=[0])
lstm_df = lstm_df.drop(index=['macro_avg', 'label_1'], level=0).reset_index(level=0, drop=True)
lstm_df.style.highlight_max(color='lightgreen', axis=1).format('{:.2f}')
# Out:
# LSTM
# <style  type="text/css" >
# #T_e98fe_row0_col1,#T_e98fe_row1_col2,#T_e98fe_row2_col0,#T_e98fe_row3_col1,#T_e98fe_row3_col2,#T_e98fe_row4_col1,#T_e98fe_row5_col2,#T_e98fe_row6_col2{
#             background-color:  lightgreen;
#         }</style><table id="T_e98fe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >au_intensities</th>        <th class="col_heading level0 col1" >au_activations</th>        <th class="col_heading level0 col2" >au_intensities_activations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e98fe_level0_row0" class="row_heading level0 row0" >anger</th>
#                         <td id="T_e98fe_row0_col0" class="data row0 col0" >0.47</td>
#                         <td id="T_e98fe_row0_col1" class="data row0 col1" >0.63</td>
#                         <td id="T_e98fe_row0_col2" class="data row0 col2" >0.57</td>
#             </tr>
#             <tr>
#                         <th id="T_e98fe_level0_row1" class="row_heading level0 row1" >disgust</th>
#                         <td id="T_e98fe_row1_col0" class="data row1 col0" >0.49</td>
#                         <td id="T_e98fe_row1_col1" class="data row1 col1" >0.42</td>
#                         <td id="T_e98fe_row1_col2" class="data row1 col2" >0.57</td>
#             </tr>
#             <tr>
#                         <th id="T_e98fe_level0_row2" class="row_heading level0 row2" >fear</th>
#                         <td id="T_e98fe_row2_col0" class="data row2 col0" >0.79</td>
#                         <td id="T_e98fe_row2_col1" class="data row2 col1" >0.68</td>
#                         <td id="T_e98fe_row2_col2" class="data row2 col2" >0.70</td>
#             </tr>
#             <tr>
#                         <th id="T_e98fe_level0_row3" class="row_heading level0 row3" >happiness</th>
#                         <td id="T_e98fe_row3_col0" class="data row3 col0" >0.60</td>
#                         <td id="T_e98fe_row3_col1" class="data row3 col1" >0.64</td>
#                         <td id="T_e98fe_row3_col2" class="data row3 col2" >0.64</td>
#             </tr>
#             <tr>
#                         <th id="T_e98fe_level0_row4" class="row_heading level0 row4" >sadness</th>
#                         <td id="T_e98fe_row4_col0" class="data row4 col0" >0.49</td>
#                         <td id="T_e98fe_row4_col1" class="data row4 col1" >0.66</td>
#                         <td id="T_e98fe_row4_col2" class="data row4 col2" >0.49</td>
#             </tr>
#             <tr>
#                         <th id="T_e98fe_level0_row5" class="row_heading level0 row5" >surprise</th>
#                         <td id="T_e98fe_row5_col0" class="data row5 col0" >0.58</td>
#                         <td id="T_e98fe_row5_col1" class="data row5 col1" >0.55</td>
#                         <td id="T_e98fe_row5_col2" class="data row5 col2" >0.59</td>
#             </tr>
#             <tr>
#                         <th id="T_e98fe_level0_row6" class="row_heading level0 row6" >valence</th>
#                         <td id="T_e98fe_row6_col0" class="data row6 col0" >0.52</td>
#                         <td id="T_e98fe_row6_col1" class="data row6 col1" >0.58</td>
#                         <td id="T_e98fe_row6_col2" class="data row6 col2" >0.60</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Tabella finale con lo score massimo di ogni modello

# %%
df_list = [logistic_df, linear_df, kernel_df, lstm_df]
max_values_list = []
for df in df_list:
    max_values_list.append(df.max(axis=1))

score_df = pd.concat(max_values_list, axis=1, sort=False)
score_df = score_df.T.rename(index={0:'logistic_regression', 1:'linear_SVM', 2:'kernel_SVM', 3:'LSTM'})
display(score_df.style.highlight_max(color = 'lightgreen').format('{:.2f}'))
# Out:
# <style  type="text/css" >
# #T_73b26_row0_col3,#T_73b26_row0_col5,#T_73b26_row0_col6,#T_73b26_row1_col0,#T_73b26_row1_col1,#T_73b26_row3_col2,#T_73b26_row3_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_73b26_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >anger</th>        <th class="col_heading level0 col1" >disgust</th>        <th class="col_heading level0 col2" >fear</th>        <th class="col_heading level0 col3" >happiness</th>        <th class="col_heading level0 col4" >sadness</th>        <th class="col_heading level0 col5" >surprise</th>        <th class="col_heading level0 col6" >valence</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73b26_level0_row0" class="row_heading level0 row0" >logistic_regression</th>
#                         <td id="T_73b26_row0_col0" class="data row0 col0" >0.63</td>
#                         <td id="T_73b26_row0_col1" class="data row0 col1" >0.63</td>
#                         <td id="T_73b26_row0_col2" class="data row0 col2" >0.74</td>
#                         <td id="T_73b26_row0_col3" class="data row0 col3" >0.68</td>
#                         <td id="T_73b26_row0_col4" class="data row0 col4" >0.62</td>
#                         <td id="T_73b26_row0_col5" class="data row0 col5" >0.62</td>
#                         <td id="T_73b26_row0_col6" class="data row0 col6" >0.64</td>
#             </tr>
#             <tr>
#                         <th id="T_73b26_level0_row1" class="row_heading level0 row1" >linear_SVM</th>
#                         <td id="T_73b26_row1_col0" class="data row1 col0" >0.65</td>
#                         <td id="T_73b26_row1_col1" class="data row1 col1" >0.69</td>
#                         <td id="T_73b26_row1_col2" class="data row1 col2" >0.71</td>
#                         <td id="T_73b26_row1_col3" class="data row1 col3" >0.66</td>
#                         <td id="T_73b26_row1_col4" class="data row1 col4" >0.64</td>
#                         <td id="T_73b26_row1_col5" class="data row1 col5" >0.61</td>
#                         <td id="T_73b26_row1_col6" class="data row1 col6" >0.62</td>
#             </tr>
#             <tr>
#                         <th id="T_73b26_level0_row2" class="row_heading level0 row2" >kernel_SVM</th>
#                         <td id="T_73b26_row2_col0" class="data row2 col0" >0.61</td>
#                         <td id="T_73b26_row2_col1" class="data row2 col1" >0.67</td>
#                         <td id="T_73b26_row2_col2" class="data row2 col2" >0.66</td>
#                         <td id="T_73b26_row2_col3" class="data row2 col3" >0.66</td>
#                         <td id="T_73b26_row2_col4" class="data row2 col4" >0.58</td>
#                         <td id="T_73b26_row2_col5" class="data row2 col5" >0.56</td>
#                         <td id="T_73b26_row2_col6" class="data row2 col6" >0.63</td>
#             </tr>
#             <tr>
#                         <th id="T_73b26_level0_row3" class="row_heading level0 row3" >LSTM</th>
#                         <td id="T_73b26_row3_col0" class="data row3 col0" >0.63</td>
#                         <td id="T_73b26_row3_col1" class="data row3 col1" >0.57</td>
#                         <td id="T_73b26_row3_col2" class="data row3 col2" >0.79</td>
#                         <td id="T_73b26_row3_col3" class="data row3 col3" >0.64</td>
#                         <td id="T_73b26_row3_col4" class="data row3 col4" >0.66</td>
#                         <td id="T_73b26_row3_col5" class="data row3 col5" >0.59</td>
#                         <td id="T_73b26_row3_col6" class="data row3 col6" >0.60</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Confronto con dummy classifier

# %% [markdown]
# Concateno la media pesata dell'f1_score di ogni modello rispetto ad ogni emozione

# %%
csv_list = ['dummy_classifier/f1_score.csv','logistic_regression/f1_score.csv','linear_SVM/f1_score.csv','kernel_SVM/f1_score.csv']
df_list = []

for csv in csv_list:
    df = pd.read_csv(csv, header=[0,1], index_col=[0,1])
    df_list.append(df)
    
for i, df in enumerate(df_list):
    df = df.drop(columns=['tilted','frontal'], level=1)
    df = df.drop(index=['macro_avg', 'label_1'], level=0).reset_index(level=0, drop=True)
    df_list[i] = df

df = pd.read_csv('LSTM/f1_score.csv', index_col=[0,1], skiprows=[1])
df = df.drop(index=['macro_avg', 'label_1'], level=0).reset_index(level=0, drop=True)
df_list.append(df)

df = pd.concat(df_list, axis=1, sort=False)

columns_arrays = [
    ['dummy_classifier','dummy_classifier','dummy_classifier','dummy_classifier','logistic_regression','logistic_regression','logistic_regression','logistic_regression','linear_svm','linear_svm','linear_svm','linear_svm','kernel_svm','kernel_svm','kernel_svm','kernel_svm','lstm','lstm','lstm'],
    ['delaunay','au_intensities','au_activations','au_intensities_activations','delaunay','au_intensities','au_activations','au_intensities_activations','delaunay','au_intensities','au_activations','au_intensities_activations','delaunay','au_intensities','au_activations','au_intensities_activations','au_intensities','au_activations','au_intensities_activations'],
]

columns_index = pd.MultiIndex.from_arrays(columns_arrays, names=['models', 'features'])
index = ['anger','disgust','fear','happiness','sadness','surprise','valence']

macro_avg_df = pd.DataFrame(data=df.values, index=index, columns=columns_index)
macro_avg_df
# Out:
# models    dummy_classifier                                \
# features          delaunay au_intensities au_activations
# anger                 0.60           0.60           0.56
# disgust               0.60           0.55           0.61
# fear                  0.62           0.66           0.63
# happiness             0.53           0.50           0.51
# sadness               0.53           0.56           0.58
# surprise              0.53           0.53           0.52
# valence               0.53           0.45           0.45
#
# models                               logistic_regression                 \
# features  au_intensities_activations            delaunay au_intensities
# anger                           0.56                0.57           0.57
# disgust                         0.55                0.53           0.63
# fear                            0.60                0.74           0.63
# happiness                       0.48                0.59           0.65
# sadness                         0.56                0.55           0.56
# surprise                        0.53                0.57           0.60
# valence                         0.50                0.52           0.64
#
# models                                              linear_svm                 \
# features  au_activations au_intensities_activations   delaunay au_intensities
# anger               0.63                       0.60       0.58           0.63
# disgust             0.62                       0.61       0.55           0.69
# fear                0.62                       0.67       0.71           0.66
# happiness           0.68                       0.65       0.61           0.66
# sadness             0.62                       0.57       0.59           0.62
# surprise            0.58                       0.62       0.57           0.58
# valence             0.61                       0.63       0.54           0.62
#
# models                                              kernel_svm                 \
# features  au_activations au_intensities_activations   delaunay au_intensities
# anger               0.63                       0.65       0.55           0.61
# disgust             0.57                       0.65       0.67           0.63
# fear                0.63                       0.62       0.59           0.64
# happiness           0.66                       0.65       0.52           0.55
# sadness             0.61                       0.64       0.55           0.58
# surprise            0.56                       0.61       0.50           0.55
# valence             0.61                       0.60       0.48           0.52
#
# models                                                        lstm  \
# features  au_activations au_intensities_activations au_intensities
# anger               0.59                       0.52           0.47
# disgust             0.58                       0.55           0.49
# fear                0.66                       0.57           0.79
# happiness           0.66                       0.65           0.60
# sadness             0.56                       0.51           0.49
# surprise            0.55                       0.56           0.58
# valence             0.63                       0.51           0.52
#
# models
# features  au_activations au_intensities_activations
# anger               0.63                       0.57
# disgust             0.42                       0.57
# fear                0.68                       0.70
# happiness           0.64                       0.64
# sadness             0.66                       0.49
# surprise            0.55                       0.59
# valence             0.58                       0.60

# %%
df = macro_avg_df.reset_index().rename(columns={'index':'emotion'})
df = df.melt(id_vars=['emotion'], value_name='f1-score')
fg = sns.catplot(x='features', y='f1-score', hue='models', col='emotion', kind='bar', palette='deep', data=df)
fg.set_xticklabels(rotation=30)
plt.show()

# %%
fg = sns.catplot(x='emotion', y='f1-score', hue='models', col='features', kind='bar', palette='deep', col_wrap=2, data=df)
fg.set_xticklabels(rotation=30)
plt.show()

# %% [markdown]
# ## Confronto con il paper

# %% [markdown]
# ### Weighted avg

# %%
columns = ['anger','disgust','fear','happiness','sadness','surprise','valence']
data = np.array([[0.43, 0.36, 0.17, 0.71, 0.35, 0.54, 0.69]])
paper_df = pd.DataFrame(data=data, columns=columns, index=['baseline'])
paper_df
# Out:
#           anger  disgust  fear  happiness  sadness  surprise  valence
# baseline   0.43     0.36  0.17       0.71     0.35      0.54     0.69

# %%
csv_list = ['dummy_classifier/f1_score.csv','logistic_regression/f1_score.csv','linear_SVM/f1_score.csv','kernel_SVM/f1_score.csv']
df_list = []

for csv in csv_list:
    df = pd.read_csv(csv, header=[0,1], index_col=[0,1])
    df_list.append(df)
    
for i, df in enumerate(df_list):
    df = df.drop(columns=['tilted','frontal'], level=1)
    df = df.drop(index=['macro_avg', 'weighted_avg'], level=0).reset_index(level=0, drop=True)
    df_list[i] = df

df = pd.read_csv('LSTM/f1_score.csv', index_col=[0,1], skiprows=[1])
df = df.drop(index=['macro_avg', 'weighted_avg'], level=0).reset_index(level=0, drop=True)
df_list.append(df)

df = pd.concat(df_list, axis=1, sort=False)

columns_arrays = [
    ['dummy_classifier','dummy_classifier','dummy_classifier','dummy_classifier','logistic_regression','logistic_regression','logistic_regression','logistic_regression','linear_svm','linear_svm','linear_svm','linear_svm','kernel_svm','kernel_svm','kernel_svm','kernel_svm','lstm','lstm','lstm'],
    ['delaunay','au_intensities','au_activations','au_intensities_activations','delaunay','au_intensities','au_activations','au_intensities_activations','delaunay','au_intensities','au_activations','au_intensities_activations','delaunay','au_intensities','au_activations','au_intensities_activations','au_intensities','au_activations','au_intensities_activations'],
]

columns_index = pd.MultiIndex.from_arrays(columns_arrays, names=['models', 'features'])
index = ['anger','disgust','fear','happiness','sadness','surprise','valence']

label_1_df = pd.DataFrame(data=df.values, index=index, columns=columns_index)
label_1_df
# Out:
# models    dummy_classifier                                \
# features          delaunay au_intensities au_activations
# anger                 0.35           0.33           0.32
# disgust               0.27           0.21           0.30
# fear                  0.13           0.17           0.13
# happiness             0.52           0.48           0.50
# sadness               0.21           0.23           0.27
# surprise              0.39           0.36           0.40
# valence               0.56           0.45           0.48
#
# models                               logistic_regression                 \
# features  au_intensities_activations            delaunay au_intensities
# anger                           0.28                0.33           0.32
# disgust                         0.26                0.30           0.31
# fear                            0.10                0.17           0.15
# happiness                       0.47                0.59           0.65
# sadness                         0.25                0.24           0.33
# surprise                        0.39                0.47           0.45
# valence                         0.50                0.52           0.67
#
# models                                              linear_svm                 \
# features  au_activations au_intensities_activations   delaunay au_intensities
# anger               0.35                       0.35       0.37           0.37
# disgust             0.27                       0.27       0.32           0.37
# fear                0.16                       0.18       0.14           0.16
# happiness           0.69                       0.66       0.61           0.66
# sadness             0.32                       0.30       0.30           0.32
# surprise            0.47                       0.52       0.46           0.45
# valence             0.64                       0.66       0.55           0.65
#
# models                                              kernel_svm                 \
# features  au_activations au_intensities_activations   delaunay au_intensities
# anger               0.35                       0.35       0.35           0.35
# disgust             0.23                       0.31       0.31           0.33
# fear                0.15                       0.17       0.16           0.14
# happiness           0.67                       0.66       0.51           0.56
# sadness             0.34                       0.32       0.32           0.25
# surprise            0.47                       0.51       0.42           0.38
# valence             0.64                       0.63       0.49           0.56
#
# models                                                        lstm  \
# features  au_activations au_intensities_activations au_intensities
# anger               0.28                       0.32           0.39
# disgust             0.24                       0.28           0.29
# fear                0.11                       0.15           0.19
# happiness           0.67                       0.64           0.53
# sadness             0.29                       0.34           0.31
# surprise            0.44                       0.42           0.39
# valence             0.65                       0.49           0.48
#
# models
# features  au_activations au_intensities_activations
# anger               0.38                       0.34
# disgust             0.29                       0.32
# fear                0.17                       0.18
# happiness           0.66                       0.62
# sadness             0.27                       0.30
# surprise            0.33                       0.37
# valence             0.60                       0.63

# %%
best_features_df = total_df.loc[:,[('logistic_regression','au_activations'),('linear_svm', 'au_intensities'),('kernel_svm','au_activations'),('lstm','au_intensities_activations')]]
all_models_df = pd.concat([best_features_df.droplevel(1, axis=1), paper_df.T], axis=1)
display(all_models_df.style.highlight_max(color='lightgreen', axis=1).format('{:.2f}'))

melted_df = all_models_df.reset_index().rename(columns={'index':'emotion'}).melt(id_vars='emotion', var_name='models', value_name='f1-score')
fg = sns.catplot(x='emotion', y='f1-score', hue='models', kind='bar', palette='deep', data=melted_df)
fg.set_xticklabels(rotation=30)
plt.show()
# Out:
# <style  type="text/css" >
# #T_a38c3_row0_col0,#T_a38c3_row0_col1,#T_a38c3_row1_col1,#T_a38c3_row2_col3,#T_a38c3_row3_col4,#T_a38c3_row4_col0,#T_a38c3_row4_col1,#T_a38c3_row5_col3,#T_a38c3_row6_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_a38c3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >logistic_regression</th>        <th class="col_heading level0 col1" >linear_svm</th>        <th class="col_heading level0 col2" >kernel_svm</th>        <th class="col_heading level0 col3" >lstm</th>        <th class="col_heading level0 col4" >baseline</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a38c3_level0_row0" class="row_heading level0 row0" >anger</th>
#                         <td id="T_a38c3_row0_col0" class="data row0 col0" >0.63</td>
#                         <td id="T_a38c3_row0_col1" class="data row0 col1" >0.63</td>
#                         <td id="T_a38c3_row0_col2" class="data row0 col2" >0.59</td>
#                         <td id="T_a38c3_row0_col3" class="data row0 col3" >0.57</td>
#                         <td id="T_a38c3_row0_col4" class="data row0 col4" >0.43</td>
#             </tr>
#             <tr>
#                         <th id="T_a38c3_level0_row1" class="row_heading level0 row1" >disgust</th>
#                         <td id="T_a38c3_row1_col0" class="data row1 col0" >0.62</td>
#                         <td id="T_a38c3_row1_col1" class="data row1 col1" >0.69</td>
#                         <td id="T_a38c3_row1_col2" class="data row1 col2" >0.58</td>
#                         <td id="T_a38c3_row1_col3" class="data row1 col3" >0.57</td>
#                         <td id="T_a38c3_row1_col4" class="data row1 col4" >0.36</td>
#             </tr>
#             <tr>
#                         <th id="T_a38c3_level0_row2" class="row_heading level0 row2" >fear</th>
#                         <td id="T_a38c3_row2_col0" class="data row2 col0" >0.62</td>
#                         <td id="T_a38c3_row2_col1" class="data row2 col1" >0.66</td>
#                         <td id="T_a38c3_row2_col2" class="data row2 col2" >0.66</td>
#                         <td id="T_a38c3_row2_col3" class="data row2 col3" >0.70</td>
#                         <td id="T_a38c3_row2_col4" class="data row2 col4" >0.17</td>
#             </tr>
#             <tr>
#                         <th id="T_a38c3_level0_row3" class="row_heading level0 row3" >happiness</th>
#                         <td id="T_a38c3_row3_col0" class="data row3 col0" >0.68</td>
#                         <td id="T_a38c3_row3_col1" class="data row3 col1" >0.66</td>
#                         <td id="T_a38c3_row3_col2" class="data row3 col2" >0.66</td>
#                         <td id="T_a38c3_row3_col3" class="data row3 col3" >0.64</td>
#                         <td id="T_a38c3_row3_col4" class="data row3 col4" >0.71</td>
#             </tr>
#             <tr>
#                         <th id="T_a38c3_level0_row4" class="row_heading level0 row4" >sadness</th>
#                         <td id="T_a38c3_row4_col0" class="data row4 col0" >0.62</td>
#                         <td id="T_a38c3_row4_col1" class="data row4 col1" >0.62</td>
#                         <td id="T_a38c3_row4_col2" class="data row4 col2" >0.56</td>
#                         <td id="T_a38c3_row4_col3" class="data row4 col3" >0.49</td>
#                         <td id="T_a38c3_row4_col4" class="data row4 col4" >0.35</td>
#             </tr>
#             <tr>
#                         <th id="T_a38c3_level0_row5" class="row_heading level0 row5" >surprise</th>
#                         <td id="T_a38c3_row5_col0" class="data row5 col0" >0.58</td>
#                         <td id="T_a38c3_row5_col1" class="data row5 col1" >0.58</td>
#                         <td id="T_a38c3_row5_col2" class="data row5 col2" >0.55</td>
#                         <td id="T_a38c3_row5_col3" class="data row5 col3" >0.59</td>
#                         <td id="T_a38c3_row5_col4" class="data row5 col4" >0.54</td>
#             </tr>
#             <tr>
#                         <th id="T_a38c3_level0_row6" class="row_heading level0 row6" >valence</th>
#                         <td id="T_a38c3_row6_col0" class="data row6 col0" >0.61</td>
#                         <td id="T_a38c3_row6_col1" class="data row6 col1" >0.62</td>
#                         <td id="T_a38c3_row6_col2" class="data row6 col2" >0.63</td>
#                         <td id="T_a38c3_row6_col3" class="data row6 col3" >0.60</td>
#                         <td id="T_a38c3_row6_col4" class="data row6 col4" >0.69</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Weighted avg

# %%
columns = ['anger','disgust','fear','happiness','sadness','surprise','valence']
data = np.array([[0.43, 0.36, 0.17, 0.71, 0.35, 0.54, 0.69]])
paper_df = pd.DataFrame(data=data, columns=columns, index=['baseline'])
paper_df

# %%
best_features_df = total_df.loc[:,[('logistic_regression','au_activations'),('linear_svm', 'au_intensities'),('kernel_svm','au_activations'),('lstm','au_intensities_activations')]]
all_models_df = pd.concat([best_features_df.droplevel(1, axis=1), paper_df.T], axis=1)
display(all_models_df.style.highlight_max(color='lightgreen', axis=1).format('{:.2f}'))

melted_df = all_models_df.reset_index().rename(columns={'index':'emotion'}).melt(id_vars='emotion', var_name='models', value_name='f1-score')
fg = sns.catplot(x='emotion', y='f1-score', hue='models', kind='bar', palette='deep', data=melted_df)
fg.set_xticklabels(rotation=30)
plt.show()
