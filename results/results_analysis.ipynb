# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dummy_classifier.csv', header=[0,1], index_col=[0,1]).unstack(level=[0,1]).reset_index()
df.columns = ['features', 'pose', 'f1_score', 'emotion', 'value']
df
# Out:
#                        features    pose      f1_score    emotion  value
# 0                      delaunay  tilted     macro_avg      anger   0.39
# 1                      delaunay  tilted     macro_avg    disgust   0.41
# 2                      delaunay  tilted     macro_avg       fear   0.40
# 3                      delaunay  tilted     macro_avg  happiness   0.52
# 4                      delaunay  tilted     macro_avg    sadness   0.44
# ..                          ...     ...           ...        ...    ...
# 163  au_intensities_activations    none  weighted_avg       fear   0.60
# 164  au_intensities_activations    none  weighted_avg  happiness   0.48
# 165  au_intensities_activations    none  weighted_avg    sadness   0.56
# 166  au_intensities_activations    none  weighted_avg   surprise   0.53
# 167  au_intensities_activations    none  weighted_avg    valence   0.50
#
# [168 rows x 5 columns]

# %%
fg = sns.catplot(x='features', y='value', hue='pose', col='emotion', data=(df[df.f1_score=='weighted_avg']), kind='bar', palette='deep')
fg.set_xlabels('')
plt.show()

# %%
fg = sns.catplot(x='features', y='value', hue='pose', col='emotion', data=(df[df.f1_score=='macro_avg']), kind='bar', palette='deep')
fg.set_xlabels('')
plt.show()
